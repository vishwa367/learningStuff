# %% [markdown]
# ##### Class

# %%
class Animal:
    x= 2

a= Animal()
print(a.x)
# Out:
# 2

# %% [markdown]
# ##### __init__() Method

# %%
class Person:
    def __init__(self, name, age=20):   #Default constructor with age=20 default value
        self.name= name
        self.age= age

p1= Person("Vijay",28)
print(p1.name,p1.age)
p2= Person("Rahul")
print(p2.name,p2.age)
# Out:
# Vijay 28
# Rahul 20

# %% [markdown]
# ##### Self Parameter
# ###### Refers current instance of class. Used to access properties and methods of class.

# %%
class Person:
    def __init__(self, name):
        self.name= name
    def printname(self):
        print(self.name)

p1= Person("Joseph")
p1.printname()
# Out:
# Joseph

# %%
class Car:
    def __init__(self, name, mileage):
        self.name= name
        self.mileage= mileage

c1= Car("Toyota",28)
print(c1.name,c1.mileage)

c1.mileage= 25
print(c1.name,c1.mileage)
# Out:
# Toyota 28
# Toyota 25

# %%
# Add New Properties
class Person:
    def __init__(self, name):
        self.name= name

p1= Person("Tom")
p1.age= 28
p1.city= "Pune"
print(p1.name, p1.age, p1.city)
# Out:
# Tom 28 Pune
